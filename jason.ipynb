# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
training_df = pd.read_csv("chevron.csv")
print(training_df.head())
print(training_df.info())
# Out:
#    Unnamed: 0    MSN StateCode  Year   Amount   State  CO2 Emissions (Mmt)  \
# 0           0  BDFDB        AK  2015     21.0  Alaska            35.027804
# 1           1  BDPRP        AK  2015      4.0  Alaska            35.027804
# 2           2  BFFDB        AK  2015     21.0  Alaska            35.027804
# 3           3  BFPRP        AK  2015      4.0  Alaska            35.027804
# 4           4  CLPRB        AK  2015  17747.0  Alaska            35.027804
#
#    TotalNumberofInvestments  TotalAmountofAssistance
# 0                      16.0                3345612.0
# 1                      16.0                3345612.0
# 2                      16.0                3345612.0
# 3                      16.0                3345612.0
# 4                      16.0                3345612.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7595 entries, 0 to 7594
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ...

# %%
transpose_corr = corr_df.transpose()
print(transpose_corr)
# Out:
#        BDFDB     BDPRP     BFFDB     BFPRP     CLPRB     CLPRK     CLPRP  \
# AK -0.437221 -0.458453 -0.437221 -0.458453 -0.501461  0.663757 -0.549941
# AL  0.060685  0.062294  0.060685  0.062294  0.218693  0.261953  0.174375
# AR  0.871312  0.871277  0.871312  0.871277 -0.786814 -0.971414 -0.794222
# AZ -0.304124 -0.301289 -0.992989 -0.993291 -0.905087 -0.937166 -0.903377
# CA  0.180498  0.181063 -0.359339 -0.340737       NaN       NaN       NaN
# CO       NaN       NaN -0.058842 -0.072185 -0.333673 -0.884407 -0.287899
# CT  0.347165  0.348560  0.347165  0.348560       NaN       NaN       NaN
# DC       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# DE       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# FL  0.706148  0.705212  0.706148  0.705212       NaN       NaN       NaN
# GA  0.553954  0.555728  0.320815  0.322951       NaN       NaN       NaN
# HI  0.513001  0.520760  0.513001  0.520760       NaN       NaN       NaN
# ...

# %%
transpose_corr = transpose_corr.fillna(value=0)
print(transpose_corr)
# Out:
#        BDFDB     BDPRP     BFFDB     BFPRP     CLPRB     CLPRK     CLPRP  \
# AK -0.437221 -0.458453 -0.437221 -0.458453 -0.501461  0.663757 -0.549941
# AL  0.060685  0.062294  0.060685  0.062294  0.218693  0.261953  0.174375
# AR  0.871312  0.871277  0.871312  0.871277 -0.786814 -0.971414 -0.794222
# AZ -0.304124 -0.301289 -0.992989 -0.993291 -0.905087 -0.937166 -0.903377
# CA  0.180498  0.181063 -0.359339 -0.340737  0.000000  0.000000  0.000000
# CO  0.000000  0.000000 -0.058842 -0.072185 -0.333673 -0.884407 -0.287899
# CT  0.347165  0.348560  0.347165  0.348560  0.000000  0.000000  0.000000
# DC  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# DE  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# FL  0.706148  0.705212  0.706148  0.705212  0.000000  0.000000  0.000000
# GA  0.553954  0.555728  0.320815  0.322951  0.000000  0.000000  0.000000
# HI  0.513001  0.520760  0.513001  0.520760  0.000000  0.000000  0.000000
# ...

# %%
alabama_bdfdb = alabama_df.loc[alabama_df['MSN'] == 'BDFDB']
print(alabama_bdfdb)
# Out:
#       Unnamed: 0    MSN StateCode  Year  Amount    State  CO2 Emissions (Mmt)  \
# 29            29  BDFDB        AL  2015  1933.0  Alabama           119.200889
# 1548        1548  BDFDB        AL  2016  1906.0  Alabama           113.983783
# 3067        3067  BDFDB        AL  2017  1585.0  Alabama           108.594378
# 4586        4586  BDFDB        AL  2018  1652.0  Alabama           112.355471
# 6105        6105  BDFDB        AL  2019  1494.0  Alabama           106.250752
#
#       TotalNumberofInvestments  TotalAmountofAssistance
# 29                       164.0                1864412.0
# 1548                     129.0                1206793.0
# 3067                     104.0                2414699.0
# 4586                      75.0                1844186.0
# 6105                      54.0                 840218.0

# %%
corr_msn_assistanceamt = alabama_bdfdb['Amount'].corr(alabama_bdfdb['TotalAmountofAssistance'])
print(corr_msn_assistanceamt)
# Out:
# 0.06068542219308805
